# %%
import pandas as pd

# %%
df = pd.read_csv("https://econdata.s3-us-west-2.amazonaws.com/Reports/Core/RDC_Inventory_Core_Metrics_State_History.csv")
df
# Out:
#                                       month_date_yyyymm  \
# 0                                                202203
# 1                                                202203
# 2                                                202203
# 3                                                202203
# 4                                                202203
# ...                                                 ...
# 3516                                             201607
# 3517                                             201607
# 3518                                             201607
# 3519                                             201607
# 3520  quality_flag = 1:  year-over-year figures may ...
#
#                                                   state state_id  \
# 0                                             wisconsin       wi
# 1                                         west virginia       wv
# 2                                                alaska       ak
# ...

# %%
df2 = pd.read_csv("https://econdata.s3-us-west-2.amazonaws.com/Reports/Core/RDC_Inventory_Core_Metrics_County_History.csv")
df2
# Out:
#                                         month_date_yyyymm  \
# 0                                                  202203
# 1                                                  202203
# 2                                                  202203
# 3                                                  202203
# 4                                                  202203
# ...                                                   ...
# 213692                                             201607
# 213693                                             201607
# 213694                                             201607
# 213695                                             201607
# 213696  quality_flag = 1:  year-over-year figures may ...
#
#                                               county_fips    county_name  \
# 0                                                    2068     denali, ak
# 1                                                   13273    terrell, ga
# ...

# %%
df2.count()
# Out:
# month_date_yyyymm                          213697
# county_fips                                213697
# county_name                                213696
# median_listing_price                       213666
# median_listing_price_mm                    176395
# median_listing_price_yy                    175563
# active_listing_count                       213666
# active_listing_count_mm                    176309
# active_listing_count_yy                    175429
# median_days_on_market                      213696
# median_days_on_market_mm                   176416
# median_days_on_market_yy                   175581
# new_listing_count                          213669
# new_listing_count_mm                       150863
# new_listing_count_yy                       150220
# price_increased_count                      213669
# price_increased_count_mm                    49471
# price_increased_count_yy                    50006
# price_reduced_count                        213669
# ...
